# %% [markdown]
# # Импорт библиотек

# %%
import os
import torch
import tarfile
import torchvision
import torch.nn as nn
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
from PIL import Image
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torchvision import transforms
from torchvision.utils import make_grid
from torch.utils.data import random_split
from torchvision.transforms import ToTensor
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
import copy
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %% [markdown]
# # Константы

# %%
TRAIN_DS_PATH = 'chest_xray_dataset/train'
VAL_DS_PATH = 'chest_xray_dataset/val'
TEST_DS_PATH = 'chest_xray_dataset/test'

BATCH_SIZE=64
SIZE=256

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3090'

# %%
#!conda install pytorch torchvision torchaudio cudatoolkit=11.3 -y -c pytorch
#!conda install matplotlib -y
#!conda install tensorboard -y

# %% [markdown]
# # Вспомагательные функции

# %%
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc, 'val_out': out.detach(), 'val_labels': labels.detach()}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))
        
class Model(ImageClassificationBase):
    def __init__(self, arch):
        super().__init__()
        self.network = arch
        
    def forward(self, xb):
        return self.network(xb)

# %% [markdown]
# # Аугментация данных

# %%
transform_train = transforms.Compose([
    transforms.Resize([SIZE, SIZE]), 
    transforms.RandomHorizontalFlip(),
    transforms.RandomAffine(degrees=(-3, 3), translate=(0.1, 0.1), scale=(0.95, 1.05)),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    
])

transform_test = transforms.Compose([
    transforms.Resize([SIZE, SIZE]), 
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    
])

transform_example = transforms.Compose([
    transforms.Resize([SIZE, SIZE]), 
    transforms.ToTensor(),
    
])

# %% [markdown]
# # Загрузка датасета из директорий

# %%
train_ds = ImageFolder(TRAIN_DS_PATH, transform=transform_train)
val_ds = ImageFolder(VAL_DS_PATH, transform=transform_test)
test_ds = ImageFolder(TEST_DS_PATH, transform=transform_test)
example_ds = ImageFolder(TRAIN_DS_PATH, transform=transform_example)

# %% [markdown]
# Количество изображения в датасете обучения, валидации и тестовом датасете:

# %%
len(train_ds),len(val_ds),len(test_ds)
# Out:
# (5218, 625, 26)

# %% [markdown]
# # Задание подгрузчиков датасета

# %%
#!lscpu

# %%
num_workers = 0

# %%
train_dl = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=num_workers, pin_memory=True)
val_dl = DataLoader(val_ds, BATCH_SIZE, num_workers=num_workers, pin_memory=True)
test_dl = DataLoader(test_ds, BATCH_SIZE, num_workers=num_workers, pin_memory=True)

# %% [markdown]
# # Пример изображений

# %%
example_dl = DataLoader(example_ds, BATCH_SIZE, shuffle=True, num_workers=num_workers, pin_memory=True)


for images, _ in example_dl:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([64, 3, 256, 256])

# %%
import pathlib
root = pathlib.Path(TEST_DS_PATH)
classes = sorted([j.name.split('/')[-1] for j in root.iterdir()])
classes
# Out:
# ['bac', 'norm', 'vir']

# %% [markdown]
# # Метрики

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %% [markdown]
# # Инициализация модели

# %%
# efficientnet = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_efficientnet_b0', pretrained=True)

# efficientnet.classifier.fc = nn.Linear(1280, 3)

# for p in efficientnet.parameters() : 
#     p.requires_grad = False
# for p in efficientnet.classifier.parameters() : 
#     p.requires_grad = True

# %%
modelvgg = torchvision.models.vgg19(pretrained = True)

# for p in modelvgg.parameters() : 
#     p.requires_grad = False
    
modelvgg.classifier = nn.Sequential(
  nn.Linear(in_features=25088, out_features=2048) ,
  nn.ReLU(),
  nn.Linear(in_features=2048, out_features=512) ,
  nn.ReLU(),
  nn.Dropout(p=0.6), 
    
  nn.Linear(in_features=512 , out_features=3),
  nn.LogSoftmax(dim=1)  
)

# %%
model = Model(modelvgg)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Перенос Датасета и Модели с CPU на GPU

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
test_dl = DeviceDataLoader(test_dl, device)
to_device(model, device);

# %% [markdown]
# # Инициализация Tensorboard писателя

# %%
#writer = SummaryWriter('runs/pneum_experiment_1')

# %%
# get some random training images
#dataiter = iter(train_dl)
#images, labels = next(dataiter)

# create grid of images
#img_grid = torchvision.utils.make_grid(images)

# write to tensorboard
#writer.add_image('pneum_images', img_grid)

#writer.add_graph(model, images)
#writer.close()

# %% [markdown]
# # Обучение модели

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()   #eval() is called to tell model that now it is validation mode and so don't perform stuff like dropout,backpropagation etc..
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

@torch.no_grad()
def count_metrics(model, val_loader):
    model.eval()   #eval() is called to tell model that now it is validation mode and so don't perform stuff like dropout,backpropagation etc..
    outputs = [model.validation_step(batch) for batch in val_loader]
    return outputs
    # return model.validation_epoch_end(outputs)

def accuracy_multilabel(y_true, y_pred):
    n = 3
    accuracy_list = []
    for i in range(n):
        y_true_copy = copy.deepcopy(y_true)
        y_pred_copy = copy.deepcopy(y_pred)
        for j in range(n):
            if i == j:
                continue
            y_true_copy = np.where(y_true_copy == j, n, y_true_copy)
            y_pred_copy = np.where(y_pred_copy == j, n, y_pred_copy)
        accuracy_list.append(accuracy_score(y_true_copy, y_pred_copy))
    return accuracy_list

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.Adam):
    history = []
    
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train() #eval() is called to tell model that now it is training mode and so  perform stuff like dropout,backpropagation etc..
        train_losses = []
                
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        if epoch < 1:
                best_accuracy = result['val_acc']
                best_model = copy.deepcopy(model)
        else:
            if best_accuracy > result['val_acc']:
                pass
            else:
                best_accuracy = result['val_acc']
                best_model = copy.deepcopy(model)
        model.epoch_end(epoch, result)
        history.append(result)
    return history, best_model, best_accuracy

# %%
model = to_device(model, device)
evaluate(model, val_dl)
# Out:
# {'val_loss': 0.507716953754425, 'val_acc': 0.8410075902938843}

# %%
num_epochs = 100
opt_func = torch.optim.Adam
lr = 0.0000001
history, best_model, best_accuracy = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Epoch [0], train_loss: 1.0971, val_loss: 1.0942, val_acc: 0.4235
# Epoch [1], train_loss: 1.0796, val_loss: 1.0815, val_acc: 0.4422
# Epoch [2], train_loss: 1.0635, val_loss: 1.0686, val_acc: 0.4141
# Epoch [3], train_loss: 1.0446, val_loss: 1.0548, val_acc: 0.4141
# Epoch [4], train_loss: 1.0270, val_loss: 1.0395, val_acc: 0.4219
# Epoch [5], train_loss: 1.0024, val_loss: 1.0198, val_acc: 0.4547
# Epoch [6], train_loss: 0.9728, val_loss: 0.9959, val_acc: 0.5063
# Epoch [7], train_loss: 0.9369, val_loss: 0.9633, val_acc: 0.5359
# Epoch [8], train_loss: 0.8920, val_loss: 0.9251, val_acc: 0.5562
# Epoch [9], train_loss: 0.8449, val_loss: 0.8807, val_acc: 0.5578
# Epoch [10], train_loss: 0.8007, val_loss: 0.8363, val_acc: 0.5750
# Epoch [11], train_loss: 0.7549, val_loss: 0.7957, val_acc: 0.5859
# Epoch [12], train_loss: 0.7105, val_loss: 0.7629, val_acc: 0.5999
# Epoch [13], train_loss: 0.6787, val_loss: 0.7326, val_acc: 0.6366
# Epoch [14], train_loss: 0.6521, val_loss: 0.7026, val_acc: 0.6672
# Epoch [15], train_loss: 0.6346, val_loss: 0.6839, val_acc: 0.6925
# Epoch [16], train_loss: 0.6150, val_loss: 0.6705, val_acc: 0.7060
# Epoch [17], train_loss: 0.6070, val_loss: 0.6511, val_acc: 0.7194
# Epoch [18], train_loss: 0.5931, val_loss: 0.6436, val_acc: 0.7318
# Epoch [19], train_loss: 0.5847, val_loss: 0.6292, val_acc: 0.7432
# Epoch [20], train_loss: 0.5784, val_loss: 0.6198, val_acc: 0.7562
# Epoch [21], train_loss: 0.5751, val_loss: 0.6171, val_acc: 0.7531
# Epoch [22], train_loss: 0.5649, val_loss: 0.6031, val_acc: 0.7753
# Epoch [23], train_loss: 0.5506, val_loss: 0.5924, val_acc: 0.7789
# Epoch [24], train_loss: 0.5499, val_loss: 0.5961, val_acc: 0.7758
# Epoch [25], train_loss: 0.5481, val_loss: 0.5933, val_acc: 0.7773
# Epoch [26], train_loss: 0.5467, val_loss: 0.5772, val_acc: 0.7934
# Epoch [27], train_loss: 0.5426, val_loss: 0.5785, val_acc: 0.7903
# Epoch [28], train_loss: 0.5322, val_loss: 0.5718, val_acc: 0.7975
# Epoch [29], train_loss: 0.5325, val_loss: 0.5658, val_acc: 0.8002
# Epoch [30], train_loss: 0.5379, val_loss: 0.5559, val_acc: 0.8105
# Epoch [31], train_loss: 0.5262, val_loss: 0.5585, val_acc: 0.8078
# Epoch [32], train_loss: 0.5245, val_loss: 0.5498, val_acc: 0.8157
# Epoch [33], train_loss: 0.5288, val_loss: 0.5592, val_acc: 0.8074
# Epoch [34], train_loss: 0.5220, val_loss: 0.5583, val_acc: 0.8146
# Epoch [35], train_loss: 0.5161, val_loss: 0.5439, val_acc: 0.8224
# Epoch [36], train_loss: 0.5196, val_loss: 0.5461, val_acc: 0.8193
# Epoch [37], train_loss: 0.5216, val_loss: 0.5471, val_acc: 0.8229
# Epoch [38], train_loss: 0.5145, val_loss: 0.5464, val_acc: 0.8244
# Epoch [39], train_loss: 0.5106, val_loss: 0.5368, val_acc: 0.8271
# Epoch [40], train_loss: 0.5086, val_loss: 0.5448, val_acc: 0.8213
# Epoch [41], train_loss: 0.5078, val_loss: 0.5295, val_acc: 0.8327
# Epoch [42], train_loss: 0.5019, val_loss: 0.5352, val_acc: 0.8265
# Epoch [43], train_loss: 0.5075, val_loss: 0.5319, val_acc: 0.8280
# Epoch [44], train_loss: 0.5040, val_loss: 0.5333, val_acc: 0.8260
# Epoch [45], train_loss: 0.5067, val_loss: 0.5310, val_acc: 0.8280
# Epoch [46], train_loss: 0.5002, val_loss: 0.5392, val_acc: 0.8197
# Epoch [47], train_loss: 0.5015, val_loss: 0.5244, val_acc: 0.8327
# Epoch [48], train_loss: 0.5043, val_loss: 0.5321, val_acc: 0.8233
# Epoch [49], train_loss: 0.4926, val_loss: 0.5232, val_acc: 0.8296
# Epoch [50], train_loss: 0.4911, val_loss: 0.5233, val_acc: 0.8296
# Epoch [51], train_loss: 0.4909, val_loss: 0.5278, val_acc: 0.8280
# Epoch [52], train_loss: 0.4981, val_loss: 0.5192, val_acc: 0.8312
# Epoch [53], train_loss: 0.4886, val_loss: 0.5203, val_acc: 0.8296
# Epoch [54], train_loss: 0.4885, val_loss: 0.5198, val_acc: 0.8296
# Epoch [55], train_loss: 0.4803, val_loss: 0.5238, val_acc: 0.8312
# Epoch [56], train_loss: 0.4881, val_loss: 0.5232, val_acc: 0.8312
# Epoch [57], train_loss: 0.4838, val_loss: 0.5220, val_acc: 0.8312
# Epoch [58], train_loss: 0.4800, val_loss: 0.5194, val_acc: 0.8312
# Epoch [59], train_loss: 0.4772, val_loss: 0.5247, val_acc: 0.8291
# Epoch [60], train_loss: 0.4849, val_loss: 0.5160, val_acc: 0.8327
# Epoch [61], train_loss: 0.4780, val_loss: 0.5176, val_acc: 0.8312
# Epoch [62], train_loss: 0.4760, val_loss: 0.5127, val_acc: 0.8327
# Epoch [63], train_loss: 0.4773, val_loss: 0.5130, val_acc: 0.8307
# Epoch [64], train_loss: 0.4722, val_loss: 0.5196, val_acc: 0.8291
# Epoch [65], train_loss: 0.4728, val_loss: 0.5197, val_acc: 0.8312
# Epoch [66], train_loss: 0.4751, val_loss: 0.5110, val_acc: 0.8307
# Epoch [67], train_loss: 0.4733, val_loss: 0.5216, val_acc: 0.8307
# Epoch [68], train_loss: 0.4695, val_loss: 0.5107, val_acc: 0.8296
# Epoch [69], train_loss: 0.4694, val_loss: 0.5151, val_acc: 0.8312
# Epoch [70], train_loss: 0.4706, val_loss: 0.5229, val_acc: 0.8307
# Epoch [71], train_loss: 0.4696, val_loss: 0.5156, val_acc: 0.8291
# Epoch [72], train_loss: 0.4668, val_loss: 0.5101, val_acc: 0.8296
# Epoch [73], train_loss: 0.4638, val_loss: 0.5141, val_acc: 0.8296
# Epoch [74], train_loss: 0.4669, val_loss: 0.5196, val_acc: 0.8260
# Epoch [75], train_loss: 0.4582, val_loss: 0.5123, val_acc: 0.8338
# Epoch [76], train_loss: 0.4642, val_loss: 0.5215, val_acc: 0.8291
# Epoch [77], train_loss: 0.4691, val_loss: 0.5145, val_acc: 0.8307
# Epoch [78], train_loss: 0.4678, val_loss: 0.5027, val_acc: 0.8374
# Epoch [79], train_loss: 0.4580, val_loss: 0.5034, val_acc: 0.8374
# Epoch [80], train_loss: 0.4610, val_loss: 0.5070, val_acc: 0.8354
# Epoch [81], train_loss: 0.4538, val_loss: 0.5179, val_acc: 0.8307
# Epoch [82], train_loss: 0.4592, val_loss: 0.5140, val_acc: 0.8338
# Epoch [83], train_loss: 0.4542, val_loss: 0.5091, val_acc: 0.8369
# Epoch [84], train_loss: 0.4596, val_loss: 0.5177, val_acc: 0.8338
# Epoch [85], train_loss: 0.4579, val_loss: 0.5107, val_acc: 0.8354
# Epoch [86], train_loss: 0.4623, val_loss: 0.5024, val_acc: 0.8369
# Epoch [87], train_loss: 0.4556, val_loss: 0.5188, val_acc: 0.8307
# Epoch [88], train_loss: 0.4581, val_loss: 0.5205, val_acc: 0.8322
# Epoch [89], train_loss: 0.4515, val_loss: 0.5148, val_acc: 0.8354
# Epoch [90], train_loss: 0.4508, val_loss: 0.5115, val_acc: 0.8354
# Epoch [91], train_loss: 0.4509, val_loss: 0.5103, val_acc: 0.8369
# Epoch [92], train_loss: 0.4516, val_loss: 0.5155, val_acc: 0.8374
# Epoch [93], train_loss: 0.4470, val_loss: 0.5078, val_acc: 0.8385
# Epoch [94], train_loss: 0.4446, val_loss: 0.5086, val_acc: 0.8390
# Epoch [95], train_loss: 0.4491, val_loss: 0.5142, val_acc: 0.8374
# Epoch [96], train_loss: 0.4474, val_loss: 0.5072, val_acc: 0.8410
# Epoch [97], train_loss: 0.4452, val_loss: 0.5071, val_acc: 0.8390
# Epoch [98], train_loss: 0.4491, val_loss: 0.5119, val_acc: 0.8390
# Epoch [99], train_loss: 0.4425, val_loss: 0.5098, val_acc: 0.8390

# %%
model = best_model

# %%
num_epochs = 10
opt_func = torch.optim.Adam
lr = 0.000000001
history2 = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Epoch [0], train_loss: 0.4450, val_loss: 0.5074, val_acc: 0.8410
# Epoch [1], train_loss: 0.4487, val_loss: 0.5074, val_acc: 0.8410
# Epoch [2], train_loss: 0.4487, val_loss: 0.5074, val_acc: 0.8410
# Epoch [3], train_loss: 0.4426, val_loss: 0.5075, val_acc: 0.8410
# Epoch [4], train_loss: 0.4383, val_loss: 0.5076, val_acc: 0.8426
# Epoch [5], train_loss: 0.4452, val_loss: 0.5076, val_acc: 0.8426
# Epoch [6], train_loss: 0.4469, val_loss: 0.5077, val_acc: 0.8426
# Epoch [7], train_loss: 0.4429, val_loss: 0.5077, val_acc: 0.8410
# Epoch [8], train_loss: 0.4495, val_loss: 0.5077, val_acc: 0.8410
# Epoch [9], train_loss: 0.4482, val_loss: 0.5077, val_acc: 0.8410

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');
    plt.show();

# %%
plot_accuracies(history)

# %%
SAVE_PATH = 'modelvgg_augm_300522_1505.pth'

# %%
torch.save(model.state_dict(), SAVE_PATH)

# %% [markdown]
# # Подсчет метрик

# %%
model = torchvision.models.vgg19(pretrained = False)

model.classifier = nn.Sequential(
  nn.Linear(in_features=25088, out_features=2048) ,
  nn.ReLU(),
  nn.Linear(in_features=2048, out_features=512) ,
  nn.ReLU(),
  nn.Dropout(p=0.6), 
    
  nn.Linear(in_features=512 , out_features=3),
  nn.LogSoftmax(dim=1)  
)

model = Model(model)
model.load_state_dict(torch.load(SAVE_PATH))
model.eval();
to_device(model, device);

# %%
outputs = count_metrics(model, val_dl)

# %%
a_s
# Out:
# 0.8416

# %%
y_pred = np.concatenate([np.array(torch.max(outputs[i]['val_out'].cpu(), dim=1)[1]) for i in range(len(outputs))])
y_true = np.concatenate([np.array(outputs[i]['val_labels'].cpu()) for i in range(len(outputs))])

# %%
a_s = accuracy_multilabel(y_true, y_pred)
p_s = precision_score(y_true, y_pred, average=None)
r_s = recall_score(y_true, y_pred, average=None)
f1_s = f1_score(y_true, y_pred, average=None)

df2 = pd.DataFrame(np.array([a_s, p_s, r_s, f1_s]),
                   columns=['BACTERIAL', 'HEALTHY', 'VIRUS'], index=['ACC', 'PRESICION','RECALL','F1'])

cm = confusion_matrix(y_true,y_pred)
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(3), ['BACTERIAL', 'HEALTHY', 'VIRUS'], fontsize=16)
plt.yticks(range(3), ['BACTERIAL', 'HEALTHY', 'VIRUS'], fontsize=16)
plt.suptitle('Confusion Matrix', fontsize=20)
plt.show()

# %%
df2
# Out:
#            BACTERIAL   HEALTHY     VIRUS
# ACC         0.900800  0.904000  0.878400
# PRESICION   0.816901  0.962963  0.736842
# RECALL      0.958678  0.774468  0.756757
# F1          0.882129  0.858491  0.746667

# %%
print("Average Accuracy: ", accuracy_score(y_true, y_pred))
# Out:
# Average Accuracy:  0.8416
