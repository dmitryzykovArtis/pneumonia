# %% [markdown]
# # Импорт библиотек

# %%
import os
import torch
import tarfile
import torchvision
import torch.nn as nn
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torchvision import transforms
from torchvision.utils import make_grid
from torch.utils.data import random_split
from torchvision.transforms import ToTensor
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import copy

# %% [markdown]
# # Константы

# %%
TRAIN_DS_PATH = 'chest_xray_dataset/train'
VAL_DS_PATH = 'chest_xray_dataset/val'
TEST_DS_PATH = 'chest_xray_dataset/test'

BATCH_SIZE=64
SIZE=256

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3090'

# %%
#!conda install pytorch torchvision torchaudio cudatoolkit=11.3 -y -c pytorch
#!conda install matplotlib -y
#!conda install tensorboard -y

# %% [markdown]
# # Вспомагательные функции

# %%
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['train_loss'], result['val_loss'], result['val_acc']))
        
class Model(ImageClassificationBase):
    def __init__(self, arch):
        super().__init__()
        self.network = arch
        
    def forward(self, xb):
        return self.network(xb)

# %% [markdown]
# # Аугментация данных

# %%
transform_train = transforms.Compose([
    transforms.Resize([SIZE, SIZE]), 
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    
])

transform_test = transforms.Compose([
    transforms.Resize([SIZE, SIZE]), 
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    
])

transform_example = transforms.Compose([
    transforms.Resize([SIZE, SIZE]), 
    transforms.ToTensor(),
    
])

# %% [markdown]
# # Загрузка датасета из директорий

# %%
train_ds = ImageFolder(TRAIN_DS_PATH, transform=transform_train)
val_ds = ImageFolder(VAL_DS_PATH, transform=transform_test)
test_ds = ImageFolder(TEST_DS_PATH, transform=transform_test)
example_ds = ImageFolder(TRAIN_DS_PATH, transform=transform_example)

# %% [markdown]
# Количество изображения в датасете обучения, валидации и тестовом датасете:

# %%
len(train_ds),len(val_ds),len(test_ds)
# Out:
# (5218, 625, 26)

# %% [markdown]
# # Задание подгрузчиков датасета

# %%
#!lscpu

# %%
num_workers = 0

# %%
train_dl = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=num_workers, pin_memory=True)
val_dl = DataLoader(val_ds, BATCH_SIZE, num_workers=num_workers, pin_memory=True)
test_dl = DataLoader(test_ds, BATCH_SIZE, num_workers=num_workers, pin_memory=True)

# %% [markdown]
# # Пример изображений

# %%
example_dl = DataLoader(example_ds, BATCH_SIZE, shuffle=True, num_workers=num_workers, pin_memory=True)


for images, _ in example_dl:
    print('images.shape:', images.shape)
    plt.figure(figsize=(16,8))
    plt.axis('off')
    plt.imshow(make_grid(images, nrow=16).permute((1, 2, 0)))
    break
# Out:
# images.shape: torch.Size([64, 3, 256, 256])

# %%
import pathlib
root = pathlib.Path(TEST_DS_PATH)
classes = sorted([j.name.split('/')[-1] for j in root.iterdir()])
classes
# Out:
# ['bac', 'norm', 'vir']

# %% [markdown]
# # Метрики

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %% [markdown]
# # Инициализация модели

# %%
# efficientnet = torch.hub.load('NVIDIA/DeepLearningExamples:torchhub', 'nvidia_efficientnet_b0', pretrained=True)

# efficientnet.classifier.fc = nn.Linear(1280, 3)

# for p in efficientnet.parameters() : 
#     p.requires_grad = False
# for p in efficientnet.classifier.parameters() : 
#     p.requires_grad = True

# %%
modelvgg = torchvision.models.vgg19(pretrained = True)

# for p in modelvgg.parameters() : 
#     p.requires_grad = False
    
modelvgg.classifier = nn.Sequential(
  nn.Linear(in_features=25088, out_features=2048) ,
  nn.ReLU(),
  nn.Linear(in_features=2048, out_features=512) ,
  nn.ReLU(),
  nn.Dropout(p=0.6), 
    
  nn.Linear(in_features=512 , out_features=3),
  nn.LogSoftmax(dim=1)  
)

# %%
model = Model(modelvgg)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Перенос Датасета и Модели с CPU на GPU

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
test_dl = DeviceDataLoader(test_dl, device)
to_device(model, device);

# %% [markdown]
# # Инициализация Tensorboard писателя

# %%
#writer = SummaryWriter('runs/pneum_experiment_1')

# %%
# get some random training images
#dataiter = iter(train_dl)
#images, labels = next(dataiter)

# create grid of images
#img_grid = torchvision.utils.make_grid(images)

# write to tensorboard
#writer.add_image('pneum_images', img_grid)

#writer.add_graph(model, images)
#writer.close()

# %% [markdown]
# # Обучение модели

# %%
@torch.no_grad()
def evaluate(model, val_loader):
    model.eval()   #eval() is called to tell model that now it is validation mode and so don't perform stuff like dropout,backpropagation etc..
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.Adam):
    history = []
    
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        model.train() #eval() is called to tell model that now it is training mode and so  perform stuff like dropout,backpropagation etc..
        train_losses = []
                
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        if epoch < 1:
                best_accuracy = result['val_acc']
                best_model = copy.deepcopy(model)
        else:
            if best_accuracy > result['val_acc']:
                pass
            else:
                best_accuracy = result['val_acc']
                best_model = copy.deepcopy(model)
        model.epoch_end(epoch, result)
        history.append(result)
    return history, best_model, best_accuracy

# %%
model = to_device(model, device)
evaluate(model, val_dl)
# Out:
# {'val_loss': 1.1064432859420776, 'val_acc': 0.2671875059604645}

# %%
num_epochs = 100
opt_func = torch.optim.Adam
lr = 0.0000001
history, best_model, best_accuracy = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Epoch [0], train_loss: 1.0931, val_loss: 1.0892, val_acc: 0.4482
# Epoch [1], train_loss: 1.0683, val_loss: 1.0730, val_acc: 0.3844
# Epoch [2], train_loss: 1.0406, val_loss: 1.0560, val_acc: 0.3859
# Epoch [3], train_loss: 1.0079, val_loss: 1.0366, val_acc: 0.3922
# Epoch [4], train_loss: 0.9735, val_loss: 1.0135, val_acc: 0.4156
# Epoch [5], train_loss: 0.9302, val_loss: 0.9838, val_acc: 0.4594
# Epoch [6], train_loss: 0.8847, val_loss: 0.9481, val_acc: 0.4969
# Epoch [7], train_loss: 0.8351, val_loss: 0.9083, val_acc: 0.5312
# Epoch [8], train_loss: 0.7815, val_loss: 0.8714, val_acc: 0.5469
# Epoch [9], train_loss: 0.7319, val_loss: 0.8361, val_acc: 0.5655
# Epoch [10], train_loss: 0.6885, val_loss: 0.8098, val_acc: 0.6042
# Epoch [11], train_loss: 0.6547, val_loss: 0.7846, val_acc: 0.6310
# Epoch [12], train_loss: 0.6289, val_loss: 0.7647, val_acc: 0.6543
# Epoch [13], train_loss: 0.6075, val_loss: 0.7510, val_acc: 0.6698
# Epoch [14], train_loss: 0.5841, val_loss: 0.7421, val_acc: 0.6864
# Epoch [15], train_loss: 0.5785, val_loss: 0.7380, val_acc: 0.7023
# Epoch [16], train_loss: 0.5623, val_loss: 0.7320, val_acc: 0.7101
# Epoch [17], train_loss: 0.5561, val_loss: 0.7365, val_acc: 0.7142
# Epoch [18], train_loss: 0.5555, val_loss: 0.7135, val_acc: 0.7355
# Epoch [19], train_loss: 0.5398, val_loss: 0.7304, val_acc: 0.7282
# Epoch [20], train_loss: 0.5335, val_loss: 0.7165, val_acc: 0.7364
# Epoch [21], train_loss: 0.5262, val_loss: 0.7058, val_acc: 0.7411
# Epoch [22], train_loss: 0.5182, val_loss: 0.7084, val_acc: 0.7432
# Epoch [23], train_loss: 0.5170, val_loss: 0.7008, val_acc: 0.7494
# Epoch [24], train_loss: 0.5152, val_loss: 0.7014, val_acc: 0.7479
# Epoch [25], train_loss: 0.5106, val_loss: 0.6961, val_acc: 0.7510
# Epoch [26], train_loss: 0.5088, val_loss: 0.7100, val_acc: 0.7504
# Epoch [27], train_loss: 0.5094, val_loss: 0.7053, val_acc: 0.7530
# Epoch [28], train_loss: 0.4998, val_loss: 0.7009, val_acc: 0.7602
# Epoch [29], train_loss: 0.5016, val_loss: 0.7020, val_acc: 0.7566
# Epoch [30], train_loss: 0.4907, val_loss: 0.6763, val_acc: 0.7732
# Epoch [31], train_loss: 0.4911, val_loss: 0.6975, val_acc: 0.7649
# Epoch [32], train_loss: 0.4872, val_loss: 0.6806, val_acc: 0.7717
# Epoch [33], train_loss: 0.4868, val_loss: 0.6844, val_acc: 0.7748
# Epoch [34], train_loss: 0.4898, val_loss: 0.6805, val_acc: 0.7763
# Epoch [35], train_loss: 0.4834, val_loss: 0.6963, val_acc: 0.7670
# Epoch [36], train_loss: 0.4796, val_loss: 0.6867, val_acc: 0.7717
# Epoch [37], train_loss: 0.4820, val_loss: 0.6952, val_acc: 0.7701
# Epoch [38], train_loss: 0.4740, val_loss: 0.6851, val_acc: 0.7763
# Epoch [39], train_loss: 0.4754, val_loss: 0.6790, val_acc: 0.7779
# Epoch [40], train_loss: 0.4754, val_loss: 0.6859, val_acc: 0.7779
# Epoch [41], train_loss: 0.4680, val_loss: 0.7048, val_acc: 0.7654
# Epoch [42], train_loss: 0.4661, val_loss: 0.6928, val_acc: 0.7732
# Epoch [43], train_loss: 0.4652, val_loss: 0.6793, val_acc: 0.7779
# Epoch [44], train_loss: 0.4663, val_loss: 0.7001, val_acc: 0.7717
# Epoch [45], train_loss: 0.4603, val_loss: 0.6936, val_acc: 0.7732
# Epoch [46], train_loss: 0.4589, val_loss: 0.6993, val_acc: 0.7732
# Epoch [47], train_loss: 0.4632, val_loss: 0.6878, val_acc: 0.7748
# Epoch [48], train_loss: 0.4620, val_loss: 0.6936, val_acc: 0.7717
# Epoch [49], train_loss: 0.4558, val_loss: 0.6982, val_acc: 0.7732
# Epoch [50], train_loss: 0.4538, val_loss: 0.6912, val_acc: 0.7763
# Epoch [51], train_loss: 0.4523, val_loss: 0.6914, val_acc: 0.7779
# Epoch [52], train_loss: 0.4501, val_loss: 0.6782, val_acc: 0.7779
# Epoch [53], train_loss: 0.4490, val_loss: 0.7013, val_acc: 0.7748
# Epoch [54], train_loss: 0.4536, val_loss: 0.7048, val_acc: 0.7748
# Epoch [55], train_loss: 0.4442, val_loss: 0.6912, val_acc: 0.7763
# Epoch [56], train_loss: 0.4417, val_loss: 0.6900, val_acc: 0.7763
# Epoch [57], train_loss: 0.4457, val_loss: 0.7041, val_acc: 0.7701
# Epoch [58], train_loss: 0.4400, val_loss: 0.6880, val_acc: 0.7795
# Epoch [59], train_loss: 0.4398, val_loss: 0.6920, val_acc: 0.7748
# Epoch [60], train_loss: 0.4334, val_loss: 0.6960, val_acc: 0.7779
# Epoch [61], train_loss: 0.4385, val_loss: 0.6919, val_acc: 0.7779
# Epoch [62], train_loss: 0.4371, val_loss: 0.6900, val_acc: 0.7748
# Epoch [63], train_loss: 0.4340, val_loss: 0.6889, val_acc: 0.7717
# Epoch [64], train_loss: 0.4325, val_loss: 0.6980, val_acc: 0.7717
# Epoch [65], train_loss: 0.4337, val_loss: 0.7022, val_acc: 0.7701
# Epoch [66], train_loss: 0.4269, val_loss: 0.6967, val_acc: 0.7732
# Epoch [67], train_loss: 0.4283, val_loss: 0.6978, val_acc: 0.7763
# Epoch [68], train_loss: 0.4258, val_loss: 0.6834, val_acc: 0.7748
# Epoch [69], train_loss: 0.4312, val_loss: 0.6973, val_acc: 0.7732
# Epoch [70], train_loss: 0.4217, val_loss: 0.6945, val_acc: 0.7701
# Epoch [71], train_loss: 0.4279, val_loss: 0.6884, val_acc: 0.7748
# Epoch [72], train_loss: 0.4252, val_loss: 0.6969, val_acc: 0.7717
# Epoch [73], train_loss: 0.4215, val_loss: 0.6929, val_acc: 0.7717
# Epoch [74], train_loss: 0.4233, val_loss: 0.6911, val_acc: 0.7732
# Epoch [75], train_loss: 0.4204, val_loss: 0.6935, val_acc: 0.7748
# Epoch [76], train_loss: 0.4173, val_loss: 0.6950, val_acc: 0.7732
# Epoch [77], train_loss: 0.4181, val_loss: 0.7195, val_acc: 0.7685
# Epoch [78], train_loss: 0.4165, val_loss: 0.7074, val_acc: 0.7685
# Epoch [79], train_loss: 0.4147, val_loss: 0.7142, val_acc: 0.7670
# Epoch [80], train_loss: 0.4157, val_loss: 0.7164, val_acc: 0.7654
# Epoch [81], train_loss: 0.4107, val_loss: 0.7130, val_acc: 0.7701
# Epoch [82], train_loss: 0.4099, val_loss: 0.7263, val_acc: 0.7670
# Epoch [83], train_loss: 0.4098, val_loss: 0.7125, val_acc: 0.7717
# Epoch [84], train_loss: 0.4058, val_loss: 0.7203, val_acc: 0.7717
# Epoch [85], train_loss: 0.4065, val_loss: 0.7082, val_acc: 0.7732
# Epoch [86], train_loss: 0.4034, val_loss: 0.7296, val_acc: 0.7670
# Epoch [87], train_loss: 0.4029, val_loss: 0.7127, val_acc: 0.7717
# Epoch [88], train_loss: 0.4091, val_loss: 0.7163, val_acc: 0.7717
# Epoch [89], train_loss: 0.4063, val_loss: 0.7137, val_acc: 0.7701
# Epoch [90], train_loss: 0.4076, val_loss: 0.7147, val_acc: 0.7732
# Epoch [91], train_loss: 0.4034, val_loss: 0.7282, val_acc: 0.7685
# Epoch [92], train_loss: 0.3950, val_loss: 0.7383, val_acc: 0.7638
# Epoch [93], train_loss: 0.4017, val_loss: 0.7236, val_acc: 0.7732
# Epoch [94], train_loss: 0.3970, val_loss: 0.7054, val_acc: 0.7763
# Epoch [95], train_loss: 0.4016, val_loss: 0.7237, val_acc: 0.7732
# Epoch [96], train_loss: 0.3943, val_loss: 0.7130, val_acc: 0.7763
# Epoch [97], train_loss: 0.3915, val_loss: 0.7249, val_acc: 0.7717
# Epoch [98], train_loss: 0.3983, val_loss: 0.7155, val_acc: 0.7779
# Epoch [99], train_loss: 0.3933, val_loss: 0.7088, val_acc: 0.7799

# %%
model = best_model

# %%
num_epochs = 10
opt_func = torch.optim.Adam
lr = 0.000000001
history2 = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
# Out:
# Epoch [0], train_loss: 0.3896, val_loss: 0.7228, val_acc: 0.7732
# Epoch [1], train_loss: 0.3915, val_loss: 0.7227, val_acc: 0.7732
# Epoch [2], train_loss: 0.3965, val_loss: 0.7227, val_acc: 0.7732
# Epoch [3], train_loss: 0.3918, val_loss: 0.7227, val_acc: 0.7732
# Epoch [4], train_loss: 0.3955, val_loss: 0.7227, val_acc: 0.7732
# Epoch [5], train_loss: 0.3885, val_loss: 0.7226, val_acc: 0.7732
# Epoch [6], train_loss: 0.3853, val_loss: 0.7227, val_acc: 0.7732
# Epoch [7], train_loss: 0.3875, val_loss: 0.7227, val_acc: 0.7732
# Epoch [8], train_loss: 0.3935, val_loss: 0.7227, val_acc: 0.7732
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <cell line: 4>()
#       2 opt_func = torch.optim.Adam
#       3 lr = 0.000000001
# ----> 4 history2 = fit(num_epochs, lr, model, train_dl, val_dl, opt_func)
#
# Input In [22], in fit(epochs, lr, model, train_loader, val_loader, opt_func)
#      13 model.train() #eval() is called to tell model that now it is training mode and so  perform stuff like dropout,backpropagation etc..
#      14 train_losses = []
# ---> 16 for batch in train_loader:
#      17     loss = model.training_step(batch)
#      18     train_losses.append(loss)
#
# Input In [5], in DeviceDataLoader.__iter__(self)
#      30 def __iter__(self):
#      31     """Yield a batch of data after moving it to device"""
# ---> 32     for b in self.dl:
#      33         yield to_device(b, self.device)
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torch/utils/data/dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torch/utils/data/dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     568 def _next_data(self):
#     569     index = self._next_index()  # may raise StopIteration
# --> 570     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571     if self._pin_memory:
#     572         data = _utils.pin_memory.pin_memory(data)
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:49, in <listcomp>(.0)
#      47 def fetch(self, possibly_batched_index):
#      48     if self.auto_collation:
# ---> 49         data = [self.dataset[idx] for idx in possibly_batched_index]
#      50     else:
#      51         data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torchvision/datasets/folder.py:230, in DatasetFolder.__getitem__(self, index)
#     222 """
#     223 Args:
#     224     index (int): Index
#    (...)
#     227     tuple: (sample, target) where target is class_index of the target class.
#     228 """
#     229 path, target = self.samples[index]
# --> 230 sample = self.loader(path)
#     231 if self.transform is not None:
#     232     sample = self.transform(sample)
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torchvision/datasets/folder.py:269, in default_loader(path)
#     267     return accimage_loader(path)
#     268 else:
# --> 269     return pil_loader(path)
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/torchvision/datasets/folder.py:249, in pil_loader(path)
#     247 with open(path, "rb") as f:
#     248     img = Image.open(f)
# --> 249     return img.convert("RGB")
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/PIL/Image.py:889, in Image.convert(self, mode, matrix, dither, palette, colors)
#     847 def convert(self, mode=None, matrix=None, dither=None, palette=WEB, colors=256):
#     848     """
#     849     Returns a converted copy of this image. For the "P" mode, this
#     850     method translates pixels through the palette.  If mode is
#    (...)
#     886     :returns: An :py:class:`~PIL.Image.Image` object.
#     887     """
# --> 889     self.load()
#     891     has_transparency = self.info.get("transparency") is not None
#     892     if not mode and self.mode == "P":
#     893         # determine default mode
#
# File ~/miniconda3/envs/pneu/lib/python3.10/site-packages/PIL/ImageFile.py:253, in ImageFile.load(self)
#     247         raise OSError(
#     248             "image file is truncated "
#     249             f"({len(b)} bytes not processed)"
#     250         )
#     252 b = b + s
# --> 253 n, err_code = decoder.decode(b)
#     254 if n < 0:
#     255     break
#
# KeyboardInterrupt:

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');
    plt.show();

# %%
plot_accuracies(history)
